# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('/content/WorldCupMatches.csv')
df
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
df.shape
# Out:
# (852, 20)

# %%
df.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
# ...

# %%
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...

# %%
df.tail()
# Out:
#      Year              Datetime                     Stage  \
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=852, step=1)

# %%
df[200:210]
# Out:
#      Year              Datetime    Stage                  Stadium  \
# 200  1970  31 May 1970 - 12:00   Group 1           Estadio Azteca
# 201  1970  02 Jun 1970 - 16:00   Group 2               Cuauhtemoc
# 202  1970  02 Jun 1970 - 16:00   Group 4  Nou Camp - Estadio Le�n
# 203  1970  02 Jun 1970 - 16:00   Group 3                  Jalisco
# 204  1970  03 Jun 1970 - 16:00   Group 2               Luis Dosal
# 205  1970  03 Jun 1970 - 16:00   Group 4  Nou Camp - Estadio Le�n
# 206  1970  03 Jun 1970 - 16:00   Group 3                  Jalisco
# 207  1970  03 Jun 1970 - 16:00   Group 1           Estadio Azteca
# 208  1970  06 Jun 1970 - 16:00   Group 2               Cuauhtemoc
# 209  1970  06 Jun 1970 - 16:00   Group 4  Nou Camp - Estadio Le�n
#
#              City Home Team Name  Home Team Goals  Away Team Goals  \
# 200  Mexico City          Mexico                0                0
# 201       Puebla         Uruguay                2                0
# ...

# %%
df['Attendance'].max()
# Out:
# 173850.0

# %%
df['Attendance'].min()
# Out:
# 2000.0

# %%
df['Attendance'].mean()
# Out:
# 45164.8

# %%
df['RoundID'].mean()
# Out:
# 10661772.591549296

# %%
df['RoundID'].median()
# Out:
# 337.0

# %%
df['Attendance'].mode()
# Out:
# 0    43000.0
# 1    45000.0
# Name: Attendance, dtype: float64

# %%
df.dtypes.value_counts()
# Out:
# object     12
# int64       7
# float64     1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Year                      int64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals           int64
# Away Team Goals           int64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals      int64
# Half-time Away Goals      int64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                   int64
# MatchID                   int64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
df['City']
# Out:
# 0          Montevideo
# 1          Montevideo
# 2          Montevideo
# 3          Montevideo
# 4          Montevideo
#             ...
# 847          Salvador
# 848    Belo Horizonte
# 849         Sao Paulo
# 850          Brasilia
# 851    Rio De Janeiro
# Name: City, Length: 852, dtype: object

# %%
df['Home Team Goals'].max()
# Out:
# 10

# %%
df['Home Team Goals'].describe()
# Out:
# count    852.000000
# mean       1.811033
# std        1.610255
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       10.000000
# Name: Home Team Goals, dtype: float64

# %%
df.sort_values(by='Attendance')
# Out:
#      Year              Datetime           Stage  \
# 9    1930  19 Jul 1930 - 12:50          Group 1
# 3    1930  14 Jul 1930 - 14:50          Group 3
# 127  1958  17 Jun 1958 - 19:00          Group 3
# 27   1934  31 May 1934 - 16:30   Quarter-finals
# 67   1950  02 Jul 1950 - 15:40          Group 1
# ..    ...                   ...             ...
# 63   1950  01 Jul 1950 - 15:00          Group 1
# 71   1950  13 Jul 1950 - 15:00          Group 6
# 74   1950  16 Jul 1950 - 15:00          Group 6
# 823  2014  30 Jun 2014 - 17:00      Round of 16
# 841  2014  30 Jun 2014 - 17:00      Round of 16
#
#                                        Stadium             City  \
# 9                           Estadio Centenario      Montevideo
# 3                                      Pocitos      Montevideo
# 127                            Rasunda Stadium           Solna
# 27                                    San Siro           Milan
# 67                                  Eucaliptos    Porto Alegre
# ...

# %%
df['Referee'].describe()
# Out:
# count                       852
# unique                      366
# top       Ravshan IRMATOV (UZB)
# freq                         10
# Name: Referee, dtype: object

# %%
df['Stadium'].describe()
# Out:
# count                852
# unique               181
# top       Estadio Azteca
# freq                  19
# Name: Stadium, dtype: object

# %%
df['Attendance'].value_counts()
# Out:
# Attendance
# 45000.0    13
# 43000.0    13
# 52000.0    11
# 65000.0     9
# 25000.0     8
#            ..
# 23800.0     1
# 55100.0     1
# 27000.0     1
# 81100.0     1
# 20200.0     1
# Name: count, Length: 622, dtype: int64

# %%
df['Stage'].value_counts()
# Out:
# Stage
# Round of 16                 72
# Quarter-finals              66
# Group 1                     62
# Group A                     60
# Group B                     60
# Group 2                     59
# Group 3                     56
# Group 4                     55
# Group C                     48
# Group D                     48
# Group E                     48
# Group F                     48
# Semi-finals                 36
# Group G                     30
# Group H                     30
# Final                       20
# Match for third place       15
# Group 6                     12
# First round                  9
# Preliminary round            8
# Group 5                      6
# Third place                  2
# Play-off for third place     2
# Name: count, dtype: int64

# %%
df[df.RoundID>=200]
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
df['Win conditions']
# Out:
# 0
# 1
# 2
# 3
# 4
#                        ...
# 847    Netherlands win on penalties (4 - 3)
# 848
# 849      Argentina win on penalties (2 - 4)
# 850
# 851            Germany win after extra time
# Name: Win conditions, Length: 852, dtype: object

# %%
df.groupby('City').count()
# Out:
#                 Year  Datetime  Stage  Stadium  Home Team Name  \
# City
# Alicante           3         3      3        3               3
# Antibes            1         1      1        1               1
# Arica              7         7      7        7               7
# Barcelona          8         8      8        8               8
# Bari               5         5      5        5               5
# ...              ...       ...    ...      ...             ...
# Vina Del Mar       8         8      8        8               8
# Washington Dc      5         5      5        5               5
# Yokohama           4         4      4        4               4
# Zaragoza           3         3      3        3               3
# Zurich             5         5      5        5               5
#
#                 Home Team Goals  Away Team Goals  Away Team Name  \
# City
# Alicante                      3                3               3
# ...

# %%
df.nunique()
# Out:
# Year                     20
# Datetime                602
# Stage                    23
# Stadium                 181
# City                    151
# Home Team Name           78
# Home Team Goals          11
# Away Team Goals           7
# Away Team Name           83
# Win conditions           43
# Attendance              622
# Half-time Home Goals      7
# Half-time Away Goals      6
# Referee                 366
# Assistant 1             387
# Assistant 2             408
# RoundID                 101
# MatchID                 836
# Home Team Initials       77
# Away Team Initials       82
# dtype: int64

# %%
sns.barplot(x='City',y='Win conditions',data=df)
# Out:
# <Axes: xlabel='City', ylabel='Win conditions'>

# %%
sns.barplot(x='Half-time Home Goals',y='Half-time Away Goals',data=df)
# Out:
# <Axes: xlabel='Half-time Home Goals', ylabel='Half-time Away Goals'>

# %%
sns.jointplot(x='City',y='MatchID',data=df)

# %%
sns.pairplot(df,hue="Win conditions")

# %%
sns.pairplot(df,hue='Attendance',palette='Blues')

# %%
sns.countplot(x='Half-time Home Goals',data=df,hue='City')
# Out:
# <Axes: xlabel='Half-time Home Goals', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Year                    852
# Datetime                852
# Stage                   852
# Stadium                 852
# City                    852
# Home Team Name          852
# Home Team Goals         852
# Away Team Goals         852
# Away Team Name          852
# Win conditions          852
# Attendance              850
# Half-time Home Goals    852
# Half-time Away Goals    852
# Referee                 852
# Assistant 1             852
# Assistant 2             852
# RoundID                 852
# MatchID                 852
# Home Team Initials      852
# Away Team Initials      852
# dtype: int64

# %%
plt.plot("Win conditions")
plt.show()

# %%
win=df['Win conditions']
plt.plot(win)
plt.show()

# %%
plt.plot(win,color="green",label='win')
plt.legend()

# %%
sns.boxplot(df['Win conditions'])
# Out:
# <Axes: ylabel='Win conditions'>

# %%
df.isnull().mean()
# Out:
# Year                    0.000000
# Datetime                0.000000
# Stage                   0.000000
# Stadium                 0.000000
# City                    0.000000
# Home Team Name          0.000000
# Home Team Goals         0.000000
# Away Team Goals         0.000000
# Away Team Name          0.000000
# Win conditions          0.000000
# Attendance              0.002347
# Half-time Home Goals    0.000000
# Half-time Away Goals    0.000000
# Referee                 0.000000
# Assistant 1             0.000000
# Assistant 2             0.000000
# RoundID                 0.000000
# MatchID                 0.000000
# Home Team Initials      0.000000
# Away Team Initials      0.000000
# dtype: float64

# %%
sns.scatterplot(x='Win conditions',y='City',data=df)
# Out:
# <Axes: xlabel='Win conditions', ylabel='City'>

# %%
='Home Team Goals',data=df)sns.scatterplot(x='Home Team Name',y
# Out:
# <Axes: xlabel='Home Team Name', ylabel='Home Team Goals'>

# %%
# Out:
# <Axes: xlabel='Half-time Home Goals', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
df['Attendance'].fillna(df['Attendance'].mean())
# Out:
# 0       4444.0
# 1      18346.0
# 2      24059.0
# 3       2549.0
# 4      23409.0
#         ...
# 847    51179.0
# 848    58141.0
# 849    63267.0
# 850    68034.0
# 851    74738.0
# Name: Attendance, Length: 852, dtype: float64

# %%
df.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              2
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
sns.displot(x='Half-time Home Goals',data=df)

# %%
corr=df[['Half-time Home Goals','Home Team Goals','Half-time Home Goals']].corr()
print(corr)
# Out:
#                       Half-time Home Goals  Home Team Goals  \
# Half-time Home Goals              1.000000         0.729536
# Home Team Goals                   0.729536         1.000000
# Half-time Home Goals              1.000000         0.729536
#
#                       Half-time Home Goals
# Half-time Home Goals              1.000000
# Home Team Goals                   0.729536
# Half-time Home Goals              1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
df['Stage']
# Out:
# 0                       Group 1
# 1                       Group 4
# 2                       Group 2
# 3                       Group 3
# 4                       Group 1
#                  ...
# 847              Quarter-finals
# 848                 Semi-finals
# 849                 Semi-finals
# 850    Play-off for third place
# 851                       Final
# Name: Stage, Length: 852, dtype: object

# %%
df['Away Team Name']
# Out:
# 0           Mexico
# 1          Belgium
# 2           Brazil
# 3             Peru
# 4           France
#           ...
# 847     Costa Rica
# 848        Germany
# 849      Argentina
# 850    Netherlands
# 851      Argentina
# Name: Away Team Name, Length: 852, dtype: object

# %%
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# ...
